# %%
import numpy as np
import networkx as nx
import neonx
import py2neo

# %%
pip install ipython-cypher
# Out:
# Collecting ipython-cypher
#   Downloading https://files.pythonhosted.org/packages/93/a3/de64e243a1a3d791e21e90a524ac4ac87c33192671897fc90efee54ad38d/ipython-cypher-0.2.6.tar.gz
# Collecting neo4jrestclient>=2.1.0 (from ipython-cypher)
#   Downloading https://files.pythonhosted.org/packages/95/4c/df54ba57f5838fd1ae162462f81d589b8352c6aa17d5b2a7a42e8abba048/neo4jrestclient-2.1.1.tar.gz (73kB)
# Collecting prettytable (from ipython-cypher)
#   Downloading https://files.pythonhosted.org/packages/ef/30/4b0746848746ed5941f052479e7c23d2b56d174b82f4fd34a25e389831f5/prettytable-0.7.2.tar.bz2
# Requirement already satisfied: ipython>=1.0 in c:\users\kevin\anaconda3\lib\site-packages (from ipython-cypher) (7.6.1)
# Requirement already satisfied: requests>=2.1.0 in c:\users\kevin\anaconda3\lib\site-packages (from neo4jrestclient>=2.1.0->ipython-cypher) (2.22.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\kevin\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher) (0.4.1)
# Requirement already satisfied: pygments in c:\users\kevin\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher) (2.4.2)
# Requirement already satisfied: jedi>=0.10 in c:\users\kevin\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher) (0.13.3)
# Requirement already satisfied: traitlets>=4.2 in c:\users\kevin\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher) (4.3.2)
# Requirement already satisfied: backcall in c:\users\kevin\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher) (0.1.0)
# Requirement already satisfied: pickleshare in c:\users\kevin\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in c:\users\kevin\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher) (2.0.9)
# Requirement already satisfied: decorator in c:\users\kevin\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher) (4.4.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\kevin\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher) (41.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kevin\anaconda3\lib\site-packages (from requests>=2.1.0->neo4jrestclient>=2.1.0->ipython-cypher) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kevin\anaconda3\lib\site-packages (from requests>=2.1.0->neo4jrestclient>=2.1.0->ipython-cypher) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\kevin\anaconda3\lib\site-packages (from requests>=2.1.0->neo4jrestclient>=2.1.0->ipython-cypher) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\kevin\anaconda3\lib\site-packages (from requests>=2.1.0->neo4jrestclient>=2.1.0->ipython-cypher) (3.0.4)
# Requirement already satisfied: parso>=0.3.0 in c:\users\kevin\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=1.0->ipython-cypher) (0.5.0)
# Requirement already satisfied: six in c:\users\kevin\anaconda3\lib\site-packages (from traitlets>=4.2->ipython>=1.0->ipython-cypher) (1.12.0)
# Requirement already satisfied: ipython-genutils in c:\users\kevin\anaconda3\lib\site-packages (from traitlets>=4.2->ipython>=1.0->ipython-cypher) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\kevin\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=1.0->ipython-cypher) (0.1.7)
# Building wheels for collected packages: ipython-cypher, neo4jrestclient, prettytable
#   Building wheel for ipython-cypher (setup.py): started
#   Building wheel for ipython-cypher (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\kevin\AppData\Local\pip\Cache\wheels\0e\1e\65\1e0128677b6e6483b90894965f43dd078966270d3dda930044
#   Building wheel for neo4jrestclient (setup.py): started
#   Building wheel for neo4jrestclient (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\kevin\AppData\Local\pip\Cache\wheels\0f\db\72\c3f14a1e15e0adfa09c1bc3c163b15e5730c36516c5fce2f9b
#   Building wheel for prettytable (setup.py): started
#   Building wheel for prettytable (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\kevin\AppData\Local\pip\Cache\wheels\80\34\1c\3967380d9676d162cb59513bd9dc862d0584e045a162095606
# Successfully built ipython-cypher neo4jrestclient prettytable
# Installing collected packages: neo4jrestclient, prettytable, ipython-cypher
# Successfully installed ipython-cypher-0.2.6 neo4jrestclient-2.1.1 prettytable-0.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx
# %load_ext cypher
# %matplotlib inline

# %%
results = %cypher MATCH (p) RETURN p

g = results.get_graph()
# Out:
# 400000 rows affected.

# %%
g

# %%
(list(g.nodes()))
# Out:
# ['610020',
#  '610021',
#  '610022',
#  '610023',
#  '610024',
#  '610025',
#  '610026',
#  '610027',
#  '610028',
#  '610029',
#  '610030',
#  '610031',
#  '610032',
#  '610033',
#  '610034',
#  '610035',
#  '610036',
#  '610037',
#  '610038',
#  '610039',
#  '610040',
#  '610041',
#  '610042',
#  '610043',
#  '610044',
#  '610045',
#  '610046',
#  '610047',
#  '610048',
#  '610049',
#  '610050',
#  '610051',
#  '610052',
#  '610053',
#  '610054',
#  '610055',
#  '610056',
#  '610057',
#  '610058',
#  '610059',
#  '610060',
#  '610061',
#  '610062',
#  '610063',
#  '610064',
#  '610065',
#  '610066',
#  '610067',
#  '610068',
#  '610069',
#  '610070',
#  '610071',
#  '610072',
#  '610073',
#  '610074',
#  '610075',
#  '610076',
#  '610077',
#  '610078',
#  '610079',
#  '610080',
#  '610081',
#  '610082',
#  '610083',
#  '610084',
#  '610085',
#  '610086',
#  '610087',
#  '610088',
#  '610089',
#  '610090',
#  '610091',
#  '610092',
#  '610093',
#  '610094',
#  '610095',
#  '610096',
#  '610097',
#  '610098',
#  '610099',
#  '610100',
#  '610101',
#  '610102',
#  '610103',
#  '610104',
#  '610105',
#  '610106',
#  '610107',
#  '610108',
#  '610109',
#  '610110',
#  '610111',
#  '610112',
#  '610113',
#  '610114',
#  '610115',
#  '610116',
#  '610117',
#  '610118',
#  '610119',
#  '610120',
#  '610121',
#  '610122',
#  '610123',
#  '610124',
#  '610125',
#  '610126',
#  '610127',
#  '610128',
#  '610129',
#  '610130',
#  '610131',
#  '610132',
#  '610133',
#  '610134',
#  '610135',
#  '610136',
#  '610137',
#  '610138',
#  '610139',
#  '610140',
#  '610141',
#  '610142',
#  '610143',
#  '610144',
#  '610145',
#  '610146',
#  '610147',
#  '610148',
#  '610149',
#  '610150',
#  '610151',
#  '610152',
#  '610153',
#  '610154',
#  '610155',
#  '610156',
#  '610157',
#  '610158',
#  '610159',
#  '610160',
#  '610161',
#  '610162',
#  '610163',
#  '610164',
#  '610165',
#  '610166',
#  '610167',
#  '610168',
#  '610169',
#  '610170',
#  '610171',
#  '610172',
#  '610173',
#  '610174',
#  '610175',
#  '610176',
#  '610177',
#  '610178',
#  '610179',
#  '610180',
#  '610181',
#  '610182',
#  '610183',
#  '610184',
#  '610185',
#  '610186',
#  '610187',
#  '610188',
#  '610189',
#  '610190',
#  '610191',
#  '610192',
#  '610193',
#  '610194',
#  '610195',
#  '610196',
#  '610197',
#  '610198',
#  '610199',
#  '610200',
#  '610201',
#  '610202',
#  '610203',
#  '610204',
#  '610205',
#  '610206',
#  '610207',
#  '610208',
#  '610209',
#  '610210',
#  '610211',
#  '610212',
#  '610213',
#  '610214',
#  '610215',
#  '610216',
#  '610217',
#  '610218',
#  '610219',
#  '610220',
#  '610221',
#  '610222',
#  '610223',
#  '610224',
#  '610225',
#  '610226',
#  '610227',
#  '610228',
#  '610229',
#  '610230',
#  '610231',
#  '610232',
#  '610233',
#  '610234',
#  '610235',
#  '610236',
#  '610237',
#  '610238',
#  '610239',
#  '610240',
#  '610241',
#  '610242',
#  '610243',
#  '610244',
#  '610245',
#  '610246',
#  '610247',
#  '610248',
#  '610249',
#  '610250',
#  '610251',
#  '610252',
#  '610253',
#  '610254',
#  '610255',
#  '610256',
#  '610257',
#  '610258',
#  '610259',
#  '610260',
#  '610261',
#  '610262',
#  '610263',
#  '610264',
#  '610265',
#  '610266',
#  '610267',
#  '610268',
#  '610269',
#  '610270',
#  '610271',
#  '610272',
#  '610273',
#  '610274',
#  '610275',
#  '610276',
#  '610277',
#  '610278',
#  '610279',
#  '610280',
#  '610281',
#  '610282',
#  '610283',
#  '610284',
#  '610285',
#  '610286',
#  '610287',
#  '610288',
#  '610289',
#  '610290',
#  '610291',
#  '610292',
#  '610293',
#  '610294',
#  '610295',
#  '610296',
#  '610297',
#  '610298',
#  '610299',
#  '610300',
#  '610301',
#  '610302',
#  '610303',
#  '610304',
#  '610305',
#  '610306',
#  '610307',
#  '610308',
#  '610309',
#  '610310',
#  '610311',
#  '610312',
#  '610313',
#  '610314',
#  '610315',
#  '610316',
#  '610317',
#  '610318',
#  '610319',
#  '610320',
#  '610321',
#  '610322',
#  '610323',
#  '610324',
#  '610325',
#  '610326',
#  '610327',
#  '610328',
#  '610329',
#  '610330',
#  '610331',
#  '610332',
#  '610333',
#  '610334',
#  '610335',
#  '610336',
#  '610337',
#  '610338',
#  '610339',
#  '610340',
#  '610341',
#  '610342',
#  '610343',
#  '610344',
#  '610345',
#  '610346',
#  '610347',
#  '610348',
#  '610349',
#  '610350',
#  '610351',
#  '610352',
#  '610353',
#  '610354',
#  '610355',
#  '610356',
#  '610357',
#  '610358',
#  '610359',
#  '610360',
#  '610361',
#  '610362',
#  '610363',
#  '610364',
#  '610365',
#  '610366',
#  '610367',
#  '610368',
#  '610369',
#  '610370',
#  '610371',
#  '610372',
#  '610373',
#  '610374',
#  '610375',
#  '610376',
#  '610377',
#  '610378',
#  '610379',
#  '610380',
#  '610381',
#  '610382',
#  '610383',
#  '610384',
#  '610385',
#  '610386',
#  '610387',
#  '610388',
#  '610389',
#  '610390',
#  '610391',
#  '610392',
#  '610393',
#  '610394',
#  '610395',
#  '610396',
#  '610397',
#  '610398',
#  '610399',
#  '610400',
#  '610401',
#  '610402',
#  '610403',
#  '610404',
#  '610405',
#  '610406',
#  '610407',
#  '610408',
#  '610409',
#  '610410',
#  '610411',
#  '610412',
#  '610413',
#  '610414',
#  '610415',
#  '610416',
#  '610417',
#  '610418',
#  '610419',
#  '610420',
#  '610421',
#  '610422',
#  '610423',
#  '610424',
#  '610425',
#  '610426',
#  '610427',
#  '610428',
#  '610429',
#  '610430',
#  '610431',
#  '610432',
#  '610433',
#  '610434',
#  '610435',
#  '610436',
#  '610437',
#  '610438',
#  '610439',
#  '610440',
#  '610441',
#  '610442',
#  '610443',
#  '610444',
#  '610445',
#  '610446',
#  '610447',
#  '610448',
#  '610449',
#  '610450',
#  '610451',
#  '610452',
#  '610453',
#  '610454',
#  '610455',
#  '610456',
#  '610457',
#  '610458',
#  '610459',
#  '610460',
#  '610461',
#  '610462',
#  '610463',
#  '610464',
#  '610465',
#  '610466',
#  '610467',
#  '610468',
#  '610469',
#  '610470',
#  '610471',
#  '610472',
#  '610473',
#  '610474',
#  '610475',
#  '610476',
#  '610477',
#  '610478',
#  '610479',
#  '610480',
#  '610481',
#  '610482',
#  '610483',
#  '610484',
#  '610485',
#  '610486',
#  '610487',
#  '610488',
#  '610489',
#  '610490',
#  '610491',
#  '610492',
#  '610493',
#  '610494',
#  '610495',
#  '610496',
#  '610497',
#  '610498',
#  '610499',
#  '610500',
#  '610501',
#  '610502',
#  '610503',
#  '610504',
#  '610505',
#  '610506',
#  '610507',
#  '610508',
#  '610509',
#  '610510',
#  '610511',
#  '610512',
#  '610513',
#  '610514',
#  '610515',
#  '610516',
#  '610517',
#  '610518',
#  '610519',
#  '610520',
#  '610521',
#  '610522',
#  '610523',
#  '610524',
#  '610525',
#  '610526',
#  '610527',
#  '610528',
#  '610529',
#  '610530',
#  '610531',
#  '610532',
#  '610533',
#  '610534',
#  '610535',
#  '610536',
#  '610537',
#  '610538',
#  '610539',
#  '610540',
#  '610541',
#  '610542',
#  '610543',
#  '610544',
#  '610545',
#  '610546',
#  '610547',
#  '610548',
#  '610549',
#  '610550',
#  '610551',
#  '610552',
#  '610553',
#  '610554',
#  '610555',
#  '610556',
#  '610557',
#  '610558',
#  '610559',
#  '610560',
#  '610561',
#  '610562',
#  '610563',
#  '610564',
#  '610565',
#  '610566',
#  '610567',
#  '610568',
#  '610569',
#  '610570',
#  '610571',
#  '610572',
#  '610573',
#  '610574',
#  '610575',
#  '610576',
#  '610577',
#  '610578',
#  '610579',
#  '610580',
#  '610581',
#  '610582',
#  '610583',
#  '610584',
#  '610585',
#  '610586',
#  '610587',
#  '610588',
#  '610589',
#  '610590',
#  '610591',
#  '610592',
#  '610593',
#  '610594',
#  '610595',
#  '610596',
#  '610597',
#  '610598',
#  '610599',
#  '610600',
#  '610601',
#  '610602',
#  '610603',
#  '610604',
#  '610605',
#  '610606',
#  '610607',
#  '610608',
#  '610609',
#  '610610',
#  '610611',
#  '610612',
#  '610613',
#  '610614',
#  '610615',
#  '610616',
#  '610617',
#  '610618',
#  '610619',
#  '610620',
#  '610621',
#  '610622',
#  '610623',
#  '610624',
#  '610625',
#  '610626',
#  '610627',
#  '610628',
#  '610629',
#  '610630',
#  '610631',
#  '610632',
#  '610633',
#  '610634',
#  '610635',
#  '610636',
#  '610637',
#  '610638',
#  '610639',
#  '610640',
#  '610641',
#  '610642',
#  '610643',
#  '610644',
#  '610645',
#  '610646',
#  '610647',
#  '610648',
#  '610649',
#  '610650',
#  '610651',
#  '610652',
#  '610653',
#  '610654',
#  '610655',
#  '610656',
#  '610657',
#  '610658',
#  '610659',
#  '610660',
#  '610661',
#  '610662',
#  '610663',
#  '610664',
#  '610665',
#  '610666',
#  '610667',
#  '610668',
#  '610669',
#  '610670',
#  '610671',
#  '610672',
#  '610673',
#  '610674',
#  '610675',
#  '610676',
#  '610677',
#  '610678',
#  '610679',
#  '610680',
#  '610681',
#  '610682',
#  '610683',
#  '610684',
#  '610685',
#  '610686',
#  '610687',
#  '610688',
#  '610689',
#  '610690',
#  '610691',
#  '610692',
#  '610693',
#  '610694',
#  '610695',
#  '610696',
#  '610697',
#  '610698',
#  '610699',
#  '610700',
#  '610701',
#  '610702',
#  '610703',
#  '610704',
#  '610705',
#  '610706',
#  '610707',
#  '610708',
#  '610709',
#  '610710',
#  '610711',
#  '610712',
#  '610713',
#  '610714',
#  '610715',
#  '610716',
#  '610717',
#  '610718',
#  '610719',
#  '610720',
#  '610721',
#  '610722',
#  '610723',
#  '610724',
#  '610725',
#  '610726',
#  '610727',
#  '610728',
#  '610729',
#  '610730',
#  '610731',
#  '610732',
#  '610733',
#  '610734',
#  '610735',
#  '610736',
#  '610737',
#  '610738',
#  '610739',
#  '610740',
#  '610741',
#  '610742',
#  '610743',
#  '610744',
#  '610745',
#  '610746',
#  '610747',
#  '610748',
#  '610749',
#  '610750',
#  '610751',
#  '610752',
#  '610753',
#  '610754',
#  '610755',
#  '610756',
#  '610757',
#  '610758',
#  '610759',
#  '610760',
#  '610761',
#  '610762',
#  '610763',
#  '610764',
#  '610765',
#  '610766',
#  '610767',
#  '610768',
#  '610769',
#  '610770',
#  '610771',
#  '610772',
#  '610773',
#  '610774',
#  '610775',
#  '610776',
#  '610777',
#  '610778',
#  '610779',
#  '610780',
#  '610781',
#  '610782',
#  '610783',
#  '610784',
#  '610785',
#  '610786',
#  '610787',
#  '610788',
#  '610789',
#  '610790',
#  '610791',
#  '610792',
#  '610793',
#  '610794',
#  '610795',
#  '610796',
#  '610797',
#  '610798',
#  '610799',
#  '610800',
#  '610801',
#  '610802',
#  '610803',
#  '610804',
#  '610805',
#  '610806',
#  '610807',
#  '610808',
#  '610809',
#  '610810',
#  '610811',
#  '610812',
#  '610813',
#  '610814',
#  '610815',
#  '610816',
#  '610817',
#  '610818',
#  '610819',
#  '610820',
#  '610821',
#  '610822',
#  '610823',
#  '610824',
#  '610825',
#  '610826',
#  '610827',
#  '610828',
#  '610829',
#  '610830',
#  '610831',
#  '610832',
#  '610833',
#  '610834',
#  '610835',
#  '610836',
#  '610837',
#  '610838',
#  '610839',
#  '610840',
#  '610841',
#  '610842',
#  '610843',
#  '610844',
#  '610845',
#  '610846',
#  '610847',
#  '610848',
#  '610849',
#  '610850',
#  '610851',
#  '610852',
#  '610853',
#  '610854',
#  '610855',
#  '610856',
#  '610857',
#  '610858',
#  '610859',
#  '610860',
#  '610861',
#  '610862',
#  '610863',
#  '610864',
#  '610865',
#  '610866',
#  '610867',
#  '610868',
#  '610869',
#  '610870',
#  '610871',
#  '610872',
#  '610873',
#  '610874',
#  '610875',
#  '610876',
#  '610877',
#  '610878',
#  '610879',
#  '610880',
#  '610881',
#  '610882',
#  '610883',
#  '610884',
#  '610885',
#  '610886',
#  '610887',
#  '610888',
#  '610889',
#  '610890',
#  '610891',
#  '610892',
#  '610893',
#  '610894',
#  '610895',
#  '610896',
#  '610897',
#  '610898',
#  '610899',
#  '610900',
#  '610901',
#  '610902',
#  '610903',
#  '610904',
#  '610905',
#  '610906',
#  '610907',
#  '610908',
#  '610909',
#  '610910',
#  '610911',
#  '610912',
#  '610913',
#  '610914',
#  '610915',
#  '610916',
#  '610917',
#  '610918',
#  '610919',
#  '610920',
#  '610921',
#  '610922',
#  '610923',
#  '610924',
#  '610925',
#  '610926',
#  '610927',
#  '610928',
#  '610929',
#  '610930',
#  '610931',
#  '610932',
#  '610933',
#  '610934',
#  '610935',
#  '610936',
#  '610937',
#  '610938',
#  '610939',
#  '610940',
#  '610941',
#  '610942',
#  '610943',
#  '610944',
#  '610945',
#  '610946',
#  '610947',
#  '610948',
#  '610949',
#  '610950',
#  '610951',
#  '610952',
#  '610953',
#  '610954',
#  '610955',
#  '610956',
#  '610957',
#  '610958',
#  '610959',
#  '610960',
#  '610961',
#  '610962',
#  '610963',
#  '610964',
#  '610965',
#  '610966',
#  '610967',
#  '610968',
#  '610969',
#  '610970',
#  '610971',
#  '610972',
#  '610973',
#  '610974',
#  '610975',
#  '610976',
#  '610977',
#  '610978',
#  '610979',
#  '610980',
#  '610981',
#  '610982',
#  '610983',
#  '610984',
#  '610985',
#  '610986',
#  '610987',
#  '610988',
#  '610989',
#  '610990',
#  '610991',
#  '610992',
#  '610993',
#  '610994',
#  '610995',
#  '610996',
#  '610997',
#  '610998',
#  '610999',
#  '611000',
#  '611001',
#  '611002',
#  '611003',
#  '611004',
#  '611005',
#  '611006',
#  '611007',
#  '611008',
#  '611009',
#  '611010',
#  '611011',
#  '611012',
#  '611013',
#  '611014',
#  '611015',
#  '611016',
#  '611017',
#  '611018',
#  '611019',
#  ...]

# %%
graphs = list(nx.connected_component_subgraphs(g.to_undirected()))

# %%
graphs[0].nodes()
# Out:
# NodeView(('610020',))

# %%
pip install neonx
# Out:
# Collecting neonx
#   Downloading https://files.pythonhosted.org/packages/82/52/5a0fbf1441003208efc3f3e530cd1e8415a8b613ff5376bfe04adee753f3/neonx-0.1.1.tar.gz
# Requirement already satisfied: networkx in c:\users\kevin\anaconda3\lib\site-packages (from neonx) (2.3)
# Requirement already satisfied: requests in c:\users\kevin\anaconda3\lib\site-packages (from neonx) (2.22.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\kevin\anaconda3\lib\site-packages (from networkx->neonx) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kevin\anaconda3\lib\site-packages (from requests->neonx) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kevin\anaconda3\lib\site-packages (from requests->neonx) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\kevin\anaconda3\lib\site-packages (from requests->neonx) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\kevin\anaconda3\lib\site-packages (from requests->neonx) (3.0.4)
# Building wheels for collected packages: neonx
#   Building wheel for neonx (setup.py): started
#   Building wheel for neonx (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\kevin\AppData\Local\pip\Cache\wheels\8e\2f\f4\16169edf3b1b8d751f9092740ed040cb792a3329fc607b372d
# Successfully built neonx
# Installing collected packages: neonx
# Successfully installed neonx-0.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from neonx import neo

# %%
G=nx.path_graph(5)
G.nodes[1]['color']='blue'
G[2][3]['weight']=5

# %%
print(G.nodes[1])
G[2][3]
# Out:
# {'color': 'blue'}
# {'weight': 5}

# %%
G.adj
# Out:
# AdjacencyView({0: {1: {}}, 1: {0: {}, 2: {}}, 2: {1: {}, 3: {'weight': 5}}, 3: {2: {'weight': 5}, 4: {}}, 4: {3: {}}})

# %%
results = neo.write_to_neo("http://localhost:7474/db/data/", G, 'LINKS_TO',  'Person')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-398d8ecdc344> in <module>
# ----> 1 results = neo.write_to_neo("http://localhost:7474/db/data/", G, 'LINKS_TO',  'Person')
#
# ~\Anaconda3\lib\site-packages\neonx\neo.py in write_to_neo(server_url, graph, edge_rel_name, encoder)
#      86     batch_url = all_server_urls['batch']
#      87
# ---> 88     data = generate_data(graph, edge_rel_name, encoder)
#      89     headers = {'content-type': JSON_CONTENT_TYPE}
#      90     result = requests.post(batch_url, data=data, headers=headers)
#
# ~\Anaconda3\lib\site-packages\neonx\neo.py in generate_data(graph, edge_rel_name, encoder)
#      48             entities.append(reverse_edge)
#      49
# ---> 50     return encoder.encode(entities)
#      51
#      52
#
# TypeError: encode() argument 1 must be str, not list

# %%
import neo4j
from neo4j import GraphDatabase
import networkx as nx

driver = GraphDatabase.driver('bolt://localhost:7687', auth=("neo4j", "@Kevinvivk9091"))

# %%
pip install neo4j
# Out:
# Collecting neo4j
#   Downloading https://files.pythonhosted.org/packages/ff/94/01746058f78f3ed8909f4fdeb9614789bdf48e8dbe178a64266eb9dd7af2/neo4j-1.7.6.tar.gz
# Collecting neobolt~=1.7.15 (from neo4j)
#   Downloading https://files.pythonhosted.org/packages/0d/b2/eb7c33e1f02cd7bbaf4c237619dd8dc43fa6081f331c2d35b28deb78e259/neobolt-1.7.16.tar.gz (183kB)
# Collecting neotime~=1.7.1 (from neo4j)
#   Downloading https://files.pythonhosted.org/packages/0b/7e/ca368a8d8e288be1352d4e2df35da1e01f8aaffbf526695df71630bcb8a6/neotime-1.7.4.tar.gz
# Requirement already satisfied: pytz in c:\users\kevin\anaconda3\lib\site-packages (from neotime~=1.7.1->neo4j) (2019.1)
# Requirement already satisfied: six in c:\users\kevin\anaconda3\lib\site-packages (from neotime~=1.7.1->neo4j) (1.12.0)
# Building wheels for collected packages: neo4j, neobolt, neotime
#   Building wheel for neo4j (setup.py): started
#   Building wheel for neo4j (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\kevin\AppData\Local\pip\Cache\wheels\5f\36\4c\bde6e0d19509f6e3697caaf5a2d82039552602d114e1710a7b
#   Building wheel for neobolt (setup.py): started
#   Building wheel for neobolt (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\kevin\AppData\Local\pip\Cache\wheels\8e\51\2b\623ff6538b9f4bc9368d568a5873b765f1178fe9af807d1296
#   Building wheel for neotime (setup.py): started
#   Building wheel for neotime (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\kevin\AppData\Local\pip\Cache\wheels\d4\b4\c4\ab867cd0ac9e667f8cd269f9364fd1cb8ee75fe50f5ce97c79
# Successfully built neo4j neobolt neotime
# Installing collected packages: neobolt, neotime, neo4j
# Successfully installed neo4j-1.7.6 neobolt-1.7.16 neotime-1.7.4
# Note: you may need to restart the kernel to use updated packages.

# %%
query = """
MATCH (n)
RETURN n
"""

# %%
with driver.session() as session:
    result = session.run(query)

# This bit doesn't work
G = nx.Graph(result)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-10-88da40cdd61d> in <module>
#       3
#       4 # This bit doesn't work
# ----> 5 G = nx.Graph(result)
#
# ~\Anaconda3\lib\site-packages\networkx\classes\graph.py in __init__(self, incoming_graph_data, **attr)
#     344         # attempt to load graph with data
#     345         if incoming_graph_data is not None:
# --> 346             convert.to_networkx_graph(incoming_graph_data, create_using=self)
#     347         # load graph attributes (must be after convert)
#     348         self.graph.update(attr)
#
# ~\Anaconda3\lib\site-packages\networkx\convert.py in to_networkx_graph(data, create_using, multigraph_input)
#     163
#     164     raise nx.NetworkXError(
# --> 165         "Input is not a known data type for conversion.")
#     166
#     167
#
# NetworkXError: Input is not a known data type for conversion.

# %%
result

# %%
import ipython-cypher
# Out:
#   File "<ipython-input-14-ff4becfd316a>", line 1
#     import ipython-cypher
#                   ^
# SyntaxError: invalid syntax

# %%
import networkx as nx
# %load_ext cypher
# %matplotlib inline

results = %cypher MATCH p = ()-[]-() RETURN p

g = results.get_graph()

nx.draw(g)
# Out:
# The cypher extension is already loaded. To reload it, use:
#   %reload_ext cypher
# 506 rows affected.
# C:\Users\kevin\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\kevin\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
g.nodes(data=True)
# Out:
# NodeDataView({'0': {'tagline': 'Welcome to the Real World', 'title': 'The Matrix', 'released': 1999, 'labels': ['Movie']}, '8': {'born': 1978, 'name': 'Emil Eifrem', 'labels': ['Person']}, '7': {'born': 1952, 'name': 'Joel Silver', 'labels': ['Person']}, '6': {'born': 1965, 'name': 'Lana Wachowski', 'labels': ['Person']}, '5': {'born': 1967, 'name': 'Lilly Wachowski', 'labels': ['Person']}, '4': {'born': 1960, 'name': 'Hugo Weaving', 'labels': ['Person']}, '3': {'born': 1961, 'name': 'Laurence Fishburne', 'labels': ['Person']}, '2': {'born': 1967, 'name': 'Carrie-Anne Moss', 'labels': ['Person']}, '1': {'born': 1964, 'name': 'Keanu Reeves', 'labels': ['Person']}, '154': {'title': "Something's Gotta Give", 'released': 2003, 'labels': ['Movie']}, '87': {'tagline': 'Pain heals, Chicks dig scars... Glory lasts forever', 'title': 'The Replacements', 'released': 2000, 'labels': ['Movie']}, '100': {'tagline': 'The hottest data on earth. In the coolest head in town', 'title': 'Johnny Mnemonic', 'released': 1995, 'labels': ['Movie']}, '11': {'tagline': 'Evil has its winning ways', 'title': "The Devil's Advocate", 'released': 1997, 'labels': ['Movie']}, '10': {'tagline': 'Everything that has a beginning has an end', 'title': 'The Matrix Revolutions', 'released': 2003, 'labels': ['Movie']}, '9': {'tagline': 'Free your mind', 'title': 'The Matrix Reloaded', 'released': 2003, 'labels': ['Movie']}, '105': {'tagline': 'Everything is connected', 'title': 'Cloud Atlas', 'released': 2012, 'labels': ['Movie']}, '116': {'tagline': 'Freedom! Forever!', 'title': 'V for Vendetta', 'released': 2006, 'labels': ['Movie']}, '121': {'tagline': 'Speed has no limits', 'title': 'Speed Racer', 'released': 2008, 'labels': ['Movie']}, '128': {'tagline': 'Prepare to enter a secret world of assassins', 'title': 'Ninja Assassin', 'released': 2009, 'labels': ['Movie']}, '14': {'born': 1944, 'name': 'Taylor Hackford', 'labels': ['Person']}, '13': {'born': 1940, 'name': 'Al Pacino', 'labels': ['Person']}, '12': {'born': 1975, 'name': 'Charlize Theron', 'labels': ['Person']}, '85': {'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do', 'title': 'That Thing You Do', 'released': 1996, 'labels': ['Movie']}, '25': {'born': 1967, 'name': 'James Marshall', 'labels': ['Person']}, '15': {'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'title': 'A Few Good Men', 'released': 1992, 'labels': ['Movie']}, '23': {'born': 1957, 'name': 'Kevin Pollak', 'labels': ['Person']}, '24': {'born': 1943, 'name': 'J.T. Walsh', 'labels': ['Person']}, '28': {'born': 1961, 'name': 'Aaron Sorkin', 'labels': ['Person']}, '22': {'born': 1968, 'name': 'Cuba Gooding Jr.', 'labels': ['Person']}, '26': {'born': 1948, 'name': 'Christopher Guest', 'labels': ['Person']}, '27': {'born': 1947, 'name': 'Rob Reiner', 'labels': ['Person']}, '21': {'born': 1971, 'name': 'Noah Wyle', 'labels': ['Person']}, '20': {'born': 1966, 'name': 'Kiefer Sutherland', 'labels': ['Person']}, '19': {'born': 1958, 'name': 'Kevin Bacon', 'labels': ['Person']}, '18': {'born': 1962, 'name': 'Demi Moore', 'labels': ['Person']}, '17': {'born': 1937, 'name': 'Jack Nicholson', 'labels': ['Person']}, '16': {'born': 1962, 'name': 'Tom Cruise', 'labels': ['Person']}, '37': {'tagline': 'The rest of his life begins now.', 'title': 'Jerry Maguire', 'released': 2000, 'labels': ['Movie']}, '29': {'tagline': 'I feel the need, the need for speed.', 'title': 'Top Gun', 'released': 1986, 'labels': ['Movie']}, '52': {'tagline': 'A comedy from the heart that goes for the throat.', 'title': 'As Good as It Gets', 'released': 1997, 'labels': ['Movie']}, '152': {'tagline': "If he's crazy, what does that make you?", 'title': "One Flew Over the Cuckoo's Nest", 'released': 1975, 'labels': ['Movie']}, '141': {'tagline': "He didn't want law. He wanted justice.", 'title': 'Hof ...

# %%
g.edges
# Out:
# OutMultiEdgeView([('8', '0', 'ACTED_IN'), ('7', '0', 'PRODUCED'), ('7', '121', 'PRODUCED'), ('7', '116', 'PRODUCED'), ('7', '128', 'PRODUCED'), ('7', '10', 'PRODUCED'), ('7', '9', 'PRODUCED'), ('6', '0', 'DIRECTED'), ('6', '121', 'DIRECTED'), ('6', '121', 'WROTE'), ('6', '116', 'PRODUCED'), ('6', '116', 'WROTE'), ('6', '105', 'DIRECTED'), ('6', '128', 'PRODUCED'), ('6', '10', 'DIRECTED'), ('6', '9', 'DIRECTED'), ('5', '0', 'DIRECTED'), ('5', '121', 'DIRECTED'), ('5', '121', 'WROTE'), ('5', '116', 'PRODUCED'), ('5', '116', 'WROTE'), ('5', '128', 'PRODUCED'), ('5', '105', 'DIRECTED'), ('5', '10', 'DIRECTED'), ('5', '9', 'DIRECTED'), ('4', '0', 'ACTED_IN'), ('4', '105', 'ACTED_IN'), ('4', '116', 'ACTED_IN'), ('4', '10', 'ACTED_IN'), ('4', '9', 'ACTED_IN'), ('3', '0', 'ACTED_IN'), ('3', '10', 'ACTED_IN'), ('3', '9', 'ACTED_IN'), ('2', '0', 'ACTED_IN'), ('2', '10', 'ACTED_IN'), ('2', '9', 'ACTED_IN'), ('1', '0', 'ACTED_IN'), ('1', '154', 'ACTED_IN'), ('1', '87', 'ACTED_IN'), ('1', '100', 'ACTED_IN'), ('1', '11', 'ACTED_IN'), ('1', '10', 'ACTED_IN'), ('1', '9', 'ACTED_IN'), ('14', '11', 'DIRECTED'), ('13', '11', 'ACTED_IN'), ('12', '11', 'ACTED_IN'), ('12', '85', 'ACTED_IN'), ('25', '15', 'ACTED_IN'), ('25', '128', 'DIRECTED'), ('25', '116', 'DIRECTED'), ('23', '15', 'ACTED_IN'), ('24', '15', 'ACTED_IN'), ('24', '141', 'ACTED_IN'), ('28', '15', 'ACTED_IN'), ('28', '15', 'WROTE'), ('22', '15', 'ACTED_IN'), ('22', '56', 'ACTED_IN'), ('22', '37', 'ACTED_IN'), ('22', '52', 'ACTED_IN'), ('26', '15', 'ACTED_IN'), ('27', '15', 'DIRECTED'), ('27', '46', 'DIRECTED'), ('27', '81', 'DIRECTED'), ('27', '81', 'PRODUCED'), ('21', '15', 'ACTED_IN'), ('20', '15', 'ACTED_IN'), ('20', '46', 'ACTED_IN'), ('19', '15', 'ACTED_IN'), ('19', '144', 'ACTED_IN'), ('19', '137', 'ACTED_IN'), ('18', '15', 'ACTED_IN'), ('17', '15', 'ACTED_IN'), ('17', '52', 'ACTED_IN'), ('17', '152', 'ACTED_IN'), ('17', '154', 'ACTED_IN'), ('17', '141', 'ACTED_IN'), ('16', '15', 'ACTED_IN'), ('16', '37', 'ACTED_IN'), ('16', '29', 'ACTED_IN'), ('36', '29', 'WROTE'), ('31', '29', 'ACTED_IN'), ('35', '29', 'DIRECTED'), ('34', '29', 'ACTED_IN'), ('34', '73', 'ACTED_IN'), ('34', '67', 'ACTED_IN'), ('34', '81', 'ACTED_IN'), ('34', '78', 'ACTED_IN'), ('33', '29', 'ACTED_IN'), ('30', '29', 'ACTED_IN'), ('32', '29', 'ACTED_IN'), ('40', '37', 'ACTED_IN'), ('40', '46', 'ACTED_IN'), ('45', '37', 'PRODUCED'), ('45', '37', 'DIRECTED'), ('45', '37', 'WROTE'), ('42', '37', 'ACTED_IN'), ('42', '130', 'ACTED_IN'), ('41', '37', 'ACTED_IN'), ('169', '37', 'REVIEWED'), ('169', '87', 'REVIEWED'), ('169', '95', 'REVIEWED'), ('169', '97', 'REVIEWED'), ('169', '105', 'REVIEWED'), ('169', '111', 'REVIEWED'), ('44', '37', 'ACTED_IN'), ('38', '37', 'ACTED_IN'), ('39', '37', 'ACTED_IN'), ('43', '37', 'ACTED_IN'), ('47', '46', 'ACTED_IN'), ('51', '46', 'ACTED_IN'), ('51', '92', 'ACTED_IN'), ('49', '46', 'ACTED_IN'), ('50', '46', 'ACTED_IN'), ('48', '46', 'ACTED_IN'), ('53', '52', 'ACTED_IN'), ('53', '150', 'ACTED_IN'), ('53', '147', 'ACTED_IN'), ('54', '52', 'ACTED_IN'), ('54', '67', 'ACTED_IN'), ('55', '52', 'DIRECTED'), ('61', '56', 'DIRECTED'), ('60', '56', 'ACTED_IN'), ('60', '157', 'ACTED_IN'), ('60', '95', 'ACTED_IN'), ('58', '56', 'ACTED_IN'), ('58', '62', 'ACTED_IN'), ('59', '56', 'ACTED_IN'), ('59', '92', 'DIRECTED'), ('57', '56', 'ACTED_IN'), ('63', '62', 'ACTED_IN'), ('66', '62', 'DIRECTED'), ('64', '62', 'ACTED_IN'), ('64', '128', 'ACTED_IN'), ('65', '62', 'ACTED_IN'), ('65', '130', 'ACTED_IN'), ('71', '67', 'ACTED_IN'), ('71', '144', 'ACTED_IN'), ('71', '162', 'ACTED_IN'), ('71', '78', 'ACTED_IN'), ('71', '85', 'ACTED_IN'), ('71', '85', 'DIRECTED'), ('71', '111', 'ACTED_IN'), ('71', '105', 'ACTED_IN'), ('71', '150', 'ACTED_IN'), ('71', '130', 'ACTED_IN'), ('71', '73', 'ACTED_IN'), ('71', '161', 'ACTED_IN'), ('71', '159', 'ACTED_IN'), ('72', '67', 'DIRECTED'), ('72', '81', 'PRODUCED'), ('72', '81', 'WROTE'), ('72', '73', 'DIRECTED'), ('68', '67', 'ACTED_IN'), ('70', '67', 'ACTED_IN'), ('70', '92' ...

# %%
### py2neo trying to query neo4j

# %%
pip install py2neo
# Out:
# Collecting py2neo
#   Downloading https://files.pythonhosted.org/packages/af/41/c2d52a226b560618fe3df213a15e3f1ea3da09b8520a439756b619f3157d/py2neo-4.3.0.tar.gz (71kB)
# Requirement already satisfied: certifi in c:\users\kevin\anaconda3\lib\site-packages (from py2neo) (2019.11.28)
# Requirement already satisfied: click==7.0 in c:\users\kevin\anaconda3\lib\site-packages (from py2neo) (7.0)
# Requirement already satisfied: colorama in c:\users\kevin\anaconda3\lib\site-packages (from py2neo) (0.4.1)
# Requirement already satisfied: neobolt~=1.7.12 in c:\users\kevin\anaconda3\lib\site-packages (from py2neo) (1.7.16)
# Requirement already satisfied: neotime~=1.7.4 in c:\users\kevin\anaconda3\lib\site-packages (from py2neo) (1.7.4)
# Requirement already satisfied: prompt_toolkit~=2.0.7 in c:\users\kevin\anaconda3\lib\site-packages (from py2neo) (2.0.9)
# Collecting pygments~=2.3.1 (from py2neo)
#   Downloading https://files.pythonhosted.org/packages/13/e5/6d710c9cf96c31ac82657bcfb441df328b22df8564d58d0c4cd62612674c/Pygments-2.3.1-py2.py3-none-any.whl (849kB)
# Requirement already satisfied: pytz in c:\users\kevin\anaconda3\lib\site-packages (from py2neo) (2019.1)
# Requirement already satisfied: urllib3<1.25,>=1.23 in c:\users\kevin\anaconda3\lib\site-packages (from py2neo) (1.24.2)
# Requirement already satisfied: six in c:\users\kevin\anaconda3\lib\site-packages (from neotime~=1.7.4->py2neo) (1.12.0)
# Requirement already satisfied: wcwidth in c:\users\kevin\anaconda3\lib\site-packages (from prompt_toolkit~=2.0.7->py2neo) (0.1.7)
# Building wheels for collected packages: py2neo
#   Building wheel for py2neo (setup.py): started
#   Building wheel for py2neo (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\kevin\AppData\Local\pip\Cache\wheels\86\7d\e3\35bd456d80e796ba1f98730b629352ebab5294c942e8fdd826
# Successfully built py2neo
# Installing collected packages: pygments, py2neo
#   Found existing installation: Pygments 2.4.2
#     Uninstalling Pygments-2.4.2:
#       Successfully uninstalled Pygments-2.4.2
# Successfully installed py2neo-4.3.0 pygments-2.3.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: spyder 3.3.6 requires pyqt5<5.13; python_version >= "3", which is not installed.
# ERROR: spyder 3.3.6 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.

# %%
from py2neo import  Graph
graph = Graph("http://localhost:7474")
# %reload_ext cypher

# %%
graph.nodes.match("Person", name="Kevin Pollack").first()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-27-54f6a3e56c7e> in <module>
# ----> 1 graph.nodes.match("Person", name="Kevin Pollack").first()
#
# ~\Anaconda3\lib\site-packages\py2neo\matching.py in first(self)
#      92         :return: a single matching :class:`.Node` or :const:`None`
#      93         """
# ---> 94         return self.graph.evaluate(*self._query_and_parameters())
#      95
#      96     def _query_and_parameters(self, count=False):
#
# ~\Anaconda3\lib\site-packages\py2neo\database.py in evaluate(self, cypher, parameters, **kwparameters)
#     393                  :py:const:`None`.
#     394         """
# --> 395         return self.begin(autocommit=True).evaluate(cypher, parameters, **kwparameters)
#     396
#     397     def exists(self, subgraph):
#
# ~\Anaconda3\lib\site-packages\py2neo\database.py in evaluate(self, cypher, parameters, **kwparameters)
#     874         :returns: single return value or :const:`None`
#     875         """
# --> 876         return self.run(cypher, parameters, **kwparameters).evaluate(0)
#     877
#     878     def create(self, subgraph):
#
# ~\Anaconda3\lib\site-packages\py2neo\database.py in run(self, cypher, parameters, **kwparameters)
#     826                                              graph=self.graph,
#     827                                              keys=[],
# --> 828                                              entities=entities))
#     829         except CypherError as error:
#     830             raise GraphError.hydrate({"code": error.code, "message": error.message})
#
# ~\Anaconda3\lib\site-packages\py2neo\internal\connectors.py in run(self, statement, parameters, tx, graph, keys, entities)
#     368         hydrator = JSONHydrator(version="rest", graph=graph, keys=keys, entities=entities)
#     369         r = self._post("/db/data/transaction/%s" % (tx or "commit"), statement, hydrator.dehydrate(parameters))
# --> 370         assert r.status == 200  # TODO: other codes
#     371         try:
#     372             raw_result = hydrator.hydrate_result(r.data.decode("utf-8"))
#
# AssertionError:
